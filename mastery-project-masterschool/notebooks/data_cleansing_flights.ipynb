# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\konst\Downloads\public_flights_export_2025-10-26_210236.csv")
df
# Out:
#                                          trip_id origin_airport  destination  \
# 0        487529-2312f3154b1040f49f7011e98dd602c4            LUF    vancouver
# 1        487530-b922a53e150f4d6786551201a50354f0            JFK       fresno
# 2        487531-0ef6ac08b809485fb8e7856ffdf49c20            YEG      toronto
# 3        487533-6f4b07975a0946b28d4e3ab6dc65912b            SKF      chicago
# 4        487534-3e2cb1c8155241068975d689f4085fdf            LAX      chicago
# ...                                          ...            ...          ...
# 1901033  487519-c371342c37ca40eaa99414d80e2d139f            MDW  los angeles
# 1901034  487524-8ab2cd55751a451196e310ac476964df            YKZ       boston
# 1901035  487525-0ed54fadfc7b41f1ad8b44ee20e3ee98            YMX     san jose
# 1901036  487526-40f65ca4299641418d5de84df0d28e46            ATL    las vegas
# 1901037  487528-9e7cb7361fd24e999fd15500b5125f85            IND      phoenix
#
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                                          trip_id origin_airport  destination  \
# 0        487529-2312f3154b1040f49f7011e98dd602c4            LUF    vancouver
# 1        487530-b922a53e150f4d6786551201a50354f0            JFK       fresno
# 2        487531-0ef6ac08b809485fb8e7856ffdf49c20            YEG      toronto
# 3        487533-6f4b07975a0946b28d4e3ab6dc65912b            SKF      chicago
# 4        487534-3e2cb1c8155241068975d689f4085fdf            LAX      chicago
# ...                                          ...            ...          ...
# 1901033  487519-c371342c37ca40eaa99414d80e2d139f            MDW  los angeles
# 1901034  487524-8ab2cd55751a451196e310ac476964df            YKZ       boston
# 1901035  487525-0ed54fadfc7b41f1ad8b44ee20e3ee98            YMX     san jose
# 1901036  487526-40f65ca4299641418d5de84df0d28e46            ATL    las vegas
# 1901037  487528-9e7cb7361fd24e999fd15500b5125f85            IND      phoenix
#
# ...

# %%
df["trip_airline"] = df["trip_airline"].str.replace("Air Lines","Airlines", regex=False)
df
# Out:
#                                          trip_id origin_airport  destination  \
# 0        487529-2312f3154b1040f49f7011e98dd602c4            LUF    vancouver
# 1        487530-b922a53e150f4d6786551201a50354f0            JFK       fresno
# 2        487531-0ef6ac08b809485fb8e7856ffdf49c20            YEG      toronto
# 3        487533-6f4b07975a0946b28d4e3ab6dc65912b            SKF      chicago
# 4        487534-3e2cb1c8155241068975d689f4085fdf            LAX      chicago
# ...                                          ...            ...          ...
# 1901033  487519-c371342c37ca40eaa99414d80e2d139f            MDW  los angeles
# 1901034  487524-8ab2cd55751a451196e310ac476964df            YKZ       boston
# 1901035  487525-0ed54fadfc7b41f1ad8b44ee20e3ee98            YMX     san jose
# 1901036  487526-40f65ca4299641418d5de84df0d28e46            ATL    las vegas
# 1901037  487528-9e7cb7361fd24e999fd15500b5125f85            IND      phoenix
#
# ...
