# %%
import pandas as pd

url_flights = "https://lakehouse-masteryproject-2025.s3.eu-north-1.amazonaws.com/bronze/public_flights_export_2025-03-31_134734.csv"

flights_raw = pd.read_csv(url_flights)
df_flights = flights_raw.copy()

# %%
print(df_flights.describe())
# Out:
#               seats  checked_bags  destination_airport_lat  \
# count  1.847300e+06  1.847300e+06             1.847300e+06
# mean   1.250766e+00  6.080139e-01             3.812317e+01
# std    6.401529e-01  7.170107e-01             8.056612e+00
# min    0.000000e+00  0.000000e+00            -3.700800e+01
# 25%    1.000000e+00  0.000000e+00             3.353500e+01
# 50%    1.000000e+00  1.000000e+00             3.985800e+01
# 75%    1.000000e+00  1.000000e+00             4.240900e+01
# max    1.200000e+01  1.300000e+01             5.878900e+01
#
#        destination_airport_lon  base_fare_usd
# count             1.847300e+06   1.847300e+06
# mean             -8.328964e+01   6.442810e+02
# std               4.447461e+01   1.096380e+03
# min              -1.579270e+02   0.000000e+00
# 25%              -1.123830e+02   2.027000e+02
# 50%              -8.775200e+01   3.960700e+02
# 75%              -7.377900e+01   6.374900e+02
# max               1.747920e+02   2.998792e+04
