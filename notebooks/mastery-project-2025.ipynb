# %% [markdown]
# # ✈️ TravelTide – Mastery Project

# %% [markdown]
# # **Import Data**

# %% [markdown]
# To ensure smooth access for every notebook user and to avoid issues with large local files, I created a Lakehouse on AWS S3.
# This notebook loads the publicly available datasets directly from the **Bronze layer** of that Lakehouse.
#
# **Goal:**
#
# - Load flight, hotel, session, and user data for initial exploration
#
# ⏱️ *Note: Loading all datasets may take up to 3 minutes depending on your connection.*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Plot style
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

def load_flights():
    url = "https://lakehouse-masteryproject-2025.s3.eu-north-1.amazonaws.com/bronze/public_flights_export_2025-03-31_134734.csv"
    return pd.read_csv(url)

def load_hotels():
    url = "https://lakehouse-masteryproject-2025.s3.eu-north-1.amazonaws.com/bronze/public_hotels_export_2025-03-31_171805.csv"
    return pd.read_csv(url)

def load_sessions():
    url = "https://lakehouse-masteryproject-2025.s3.eu-north-1.amazonaws.com/bronze/public_sessions_export_2025-03-31_221253.csv"
    return pd.read_csv(url)

def load_users():
    url = "https://lakehouse-masteryproject-2025.s3.eu-north-1.amazonaws.com/bronze/public_users_export_2025-04-01_101058.csv"
    return pd.read_csv(url)

# %%
df_flights = load_flights()
df_hotels = load_hotels()
df_sessions = load_sessions()
df_users = load_users()

print("✅ Flight, hotel, session and user data loaded successfully.")
# Out:
# ✅ Flight, hotel, session and user data loaded successfully.

# %% [markdown]
# # **EDA | Cleansing | Feature Engineering**

# %% [markdown]
# This section provides a structured overview of the dataset and prepares key features for further analysis.
# The focus is both on understanding the raw data and on deriving new, relevant features based on domain-specific rules:
#
# - Dataset dimensions
# - Column names
# - Data types and missing values
# - First few sample rows
# - Statistical summary of all columns
# - Creation and validation of new features (Feature Engineering) using domain knowledge

# %% [markdown]
# ### **Flights**

# %% [markdown]
# #### Flights - Overview

# %%
# 🧭 Quick overview of the dataset

print("🔹 SHAPE:")
print(df_flights.shape)  # Rows and columns

print("\n🔹 COLUMNS:")
print(df_flights.columns.tolist())  # List of column names

print("\n🔹 TYPES & NULLS:")
df_flights.info()  # Column types, non-null counts

print("\n🔹 SAMPLE DATA:")
display(df_flights.head())  # First few rows

print("\n🔹 BASIC STATS:")
display(df_flights.describe(include='all'))  # Summary for all types

print("\n🔹 Missing Values per Column:")
missing_values_flights = df_flights.isna().sum()
missing_values_flights = missing_values_flights[missing_values_flights > 0]  # Only colmuns with missing dataa
display(missing_values_flights)
# Out:
# 🔹 SHAPE:
# (1847300, 13)
#
# 🔹 COLUMNS:
# ['trip_id', 'origin_airport', 'destination', 'destination_airport', 'seats', 'return_flight_booked', 'departure_time', 'return_time', 'checked_bags', 'trip_airline', 'destination_airport_lat', 'destination_airport_lon', 'base_fare_usd']
#
# 🔹 TYPES & NULLS:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1847300 entries, 0 to 1847299
# Data columns (total 13 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   trip_id                  object
#  1   origin_airport           object
#  2   destination              object
#  3   destination_airport      object
#  4   seats                    int64
#  5   return_flight_booked     bool
#  6   departure_time           object
#  7   return_time              object
#  8   checked_bags             int64
#  9   trip_airline             object
#  10  destination_airport_lat  float64
#  11  destination_airport_lon  float64
#  12  base_fare_usd            float64
# dtypes: bool(1), float64(3), int64(2), object(7)
# memory usage: 170.9+ MB
#
# 🔹 SAMPLE DATA:
#                                    trip_id origin_airport  destination  \
# 0  693092-7b8767746abd45219ed468d58da9f702            SJC      houston
# 1  693124-1032149a9e01427da914b17ce6ef1926            DEN     montreal
# 2  693149-0fdb31c7dc114a4d8a318f0feada365c            YEG      seattle
# 3  693169-d120c3721d0b4bcca278639c981e4322            MCF  san antonio
# 4  693181-f4a2363db0ee452f8ac8c0fe3d4ef0ad            YVR     new york
#
#   destination_airport  seats  return_flight_booked       departure_time  \
# 0                 EFD      1                  True  2023-04-02 07:00:00
# 1                 YHU      1                  True  2023-04-04 07:00:00
# 2                 SEA      2                  True  2023-04-01 10:00:00
# 3                 SKF      1                  True  2023-04-04 11:00:00
# 4                 LGA      1                  True  2023-03-31 07:00:00
#
#            return_time  checked_bags     trip_airline  \
# 0  2023-04-06 07:00:00             0  United Airlines
# 1  2023-04-17 07:00:00             0  Delta Air Lines
# 2  2023-04-07 10:00:00             0  Alaska Airlines
# 3  2023-04-05 11:00:00             0  United Airlines
# 4  2023-04-02 07:00:00             1  JetBlue Airways
#
#    destination_airport_lat  destination_airport_lon  base_fare_usd
# 0                   29.607                  -95.159         479.31
# 1                   45.517                  -73.417         575.78
# 2                   47.530                 -122.302         336.72
# 3                   29.529                  -98.279         295.37
# 4                   40.640                  -73.779         694.26
# 🔹 BASIC STATS:
#                                         trip_id origin_airport destination  \
# count                                   1847300        1847300     1847300
# unique                                  1847300            159         140
# top     577592-b92f730e10a74530b47f997a99de1497            JFK    new york
# freq                                          1         116524      249601
# mean                                        NaN            NaN         NaN
# std                                         NaN            NaN         NaN
# min                                         NaN            NaN         NaN
# 25%                                         NaN            NaN         NaN
# 50%                                         NaN            NaN         NaN
# 75%                                         NaN            NaN         NaN
# max                                         NaN            NaN         NaN
#
#        destination_airport         seats return_flight_booked  \
# count              1847300  1.847300e+06              1847300
# unique                 219           NaN                    2
# top                    LGA           NaN                 True
# freq                124948           NaN              1761160
# mean                   NaN  1.250766e+00                  NaN
# std                    NaN  6.401529e-01                  NaN
# min                    NaN  0.000000e+00                  NaN
# 25%                    NaN  1.000000e+00                  NaN
# 50%                    NaN  1.000000e+00                  NaN
# 75%                    NaN  1.000000e+00                  NaN
# max                    NaN  1.200000e+01                  NaN
#
#              departure_time          return_time  checked_bags  \
# count               1847300              1761160  1.847300e+06
# unique                17710                17964           NaN
# top     2023-03-18 07:00:00  2023-03-10 07:00:00           NaN
# freq                   2040                 1902           NaN
# mean                    NaN                  NaN  6.080139e-01
# std                     NaN                  NaN  7.170107e-01
# min                     NaN                  NaN  0.000000e+00
# 25%                     NaN                  NaN  0.000000e+00
# 50%                     NaN                  NaN  1.000000e+00
# 75%                     NaN                  NaN  1.000000e+00
# max                     NaN                  NaN  1.300000e+01
#
#            trip_airline  destination_airport_lat  destination_airport_lon  \
# count           1847300             1.847300e+06             1.847300e+06
# unique              355                      NaN                      NaN
# top     Delta Air Lines                      NaN                      NaN
# freq             265498                      NaN                      NaN
# mean                NaN             3.812317e+01            -8.328964e+01
# std                 NaN             8.056612e+00             4.447461e+01
# min                 NaN            -3.700800e+01            -1.579270e+02
# 25%                 NaN             3.353500e+01            -1.123830e+02
# 50%                 NaN             3.985800e+01            -8.775200e+01
# 75%                 NaN             4.240900e+01            -7.377900e+01
# max                 NaN             5.878900e+01             1.747920e+02
#
#         base_fare_usd
# count    1.847300e+06
# unique            NaN
# top               NaN
# freq              NaN
# mean     6.442810e+02
# std      1.096380e+03
# min      0.000000e+00
# 25%      2.027000e+02
# 50%      3.960700e+02
# 75%      6.374900e+02
# max      2.998792e+04
# 🔹 Missing Values per Column:
# return_time    86140
# dtype: int64

# %% [markdown]
# #### Flights - Cleansing

# %% [markdown]
# Ensure datetime format for time columns

# %%
# 1. Ensure datetime format for time columns
df_flights["departure_time"] = pd.to_datetime(df_flights["departure_time"], format="mixed", errors="coerce")
df_flights["return_time"] = pd.to_datetime(df_flights["return_time"], format="mixed", errors="coerce")

# %% [markdown]
# Standardize "Air Lines" to "Airlines"

# %%
df_flights['trip_airline'] = df_flights['trip_airline'].str.replace(r'\bAir\s+Lines\b', 'Airlines', regex=True)

# %% [markdown]
# Standardize "destination"

# %%
df_flights["destination"] = df_flights["destination"].str.title()

# %% [markdown]
# Checking the Null Values

# %%
df_checking_returns = df_flights[
    df_flights["return_time"].isna() &
    (df_flights["return_flight_booked"] == 0)
]

df_checking_returns
# Out:
#                                          trip_id origin_airport   destination  \
# 11       693308-c19c3b1924be45d2a3ecf4e1cb02b00e            BRO  Jacksonville
# 37       693380-abe4469e128f45228128e121ffae3710            IND       Toronto
# 72       693465-5eea628b802b4d72ac19bdd07e583745            RIC       Memphis
# 74       693471-24e5d3ade1b44196a891391464e72b90            PHL      Montreal
# 78       693484-e2781e8a180a4c72b673a3fec4e541e0            YQB  Indianapolis
# ...                                          ...            ...           ...
# 1847222  572011-7bbd2d2c52464b0692f28031eb4b357f            LGA     Milwaukee
# 1847238  572860-55d96a45342a4f139049350ef84db679            FAT      New York
# 1847247  573275-f7c56114a9334df2beff18a610117251            SEA       Houston
# 1847260  574575-f6bac49a284941c389d6c47bb1ac11ab            OAK      New York
# 1847278  575712-5dcadf5844af4b968bd03ad7b575ddc2            LUF      Edmonton
#
#         destination_airport  seats  return_flight_booked      departure_time  \
# 11                      LRF      1                 False 2023-04-06 07:00:00
# 37                      YKZ      1                 False 2023-04-07 13:00:00
# 72                      MEM      1                 False 2023-04-06 10:00:00
# 74                      YHU      2                 False 2023-09-11 17:00:00
# 78                      IND      1                 False 2023-04-05 08:00:00
# ...                     ...    ...                   ...                 ...
# 1847222                 MKE      1                 False 2023-03-30 16:00:00
# 1847238                 LGA      1                 False 2023-03-26 10:00:00
# 1847247                 IAH      1                 False 2023-03-23 07:00:00
# 1847260                 LGA      1                 False 2023-03-25 07:00:00
# 1847278                 YEG      1                 False 2023-03-25 11:00:00
#
#         return_time  checked_bags       trip_airline  destination_airport_lat  \
# 11              NaT             1    United Airlines                   30.494
# 37              NaT             1     Delta Airlines                   43.862
# 72              NaT             0     Delta Airlines                   35.042
# 74              NaT             1    United Airlines                   45.517
# 78              NaT             0    AirTran Airways                   39.717
# ...             ...           ...                ...                      ...
# 1847222         NaT             0    AirTran Airways                   42.947
# 1847238         NaT             0  American Airlines                   40.640
# 1847247         NaT             0    United Airlines                   29.607
# 1847260         NaT             1  American Airlines                   40.640
# 1847278         NaT             1         Air Canada                   53.667
#
#          destination_airport_lon  base_fare_usd
# 11                       -81.688         143.96
# 37                       -79.370          64.79
# 72                       -89.977         109.73
# 74                       -73.417         120.34
# 78                       -86.294         127.43
# ...                          ...            ...
# 1847222                  -87.896         105.57
# 1847238                  -73.779         400.75
# 1847247                  -95.159         273.24
# 1847260                  -73.779         359.61
# 1847278                 -113.467         208.37
#
# [86140 rows x 13 columns]

# %% [markdown]
# ***Conclusion***
#
# The NULL values in the `return_time` column correspond to flights where no return flight was booked (`return_flight_booked = 0`).
# This confirms that missing `return_time` values are a valid indicator of one-way trips, not data quality issues.

# %% [markdown]
# #### Flights - Feature Engineering

# %% [markdown]
# Extracting the user_id out of the trip_id

# %%
df_flights['user_id'] = df_flights['trip_id'].str.extract(r'^([^-]+)')

# %% [markdown]
# Review Results and Determine Export Strategy

# %%
df_flights = df_flights[
    ['trip_id', 'user_id', 'origin_airport', 'destination', 'destination_airport',
     'seats', 'return_flight_booked', 'departure_time', 'return_time',
     'checked_bags', 'trip_airline', 'destination_airport_lat',
     'destination_airport_lon', 'base_fare_usd']
]
df_flights

df_flights_silver = df_flights

df_flights_silver
# Out:
#                                          trip_id user_id origin_airport  \
# 0        693092-7b8767746abd45219ed468d58da9f702  693092            SJC
# 1        693124-1032149a9e01427da914b17ce6ef1926  693124            DEN
# 2        693149-0fdb31c7dc114a4d8a318f0feada365c  693149            YEG
# 3        693169-d120c3721d0b4bcca278639c981e4322  693169            MCF
# 4        693181-f4a2363db0ee452f8ac8c0fe3d4ef0ad  693181            YVR
# ...                                          ...     ...            ...
# 1847295  577017-b2a8f426280c4600b0785ab96288e1b3  577017            PHL
# 1847296  577208-77ea1560346c44a380ca8d7294d4b990  577208            TLH
# 1847297  577450-99bf2f6662f64063ac316ed5ce8f3778  577450            DEN
# 1847298  577510-350a2093a5b7429b8f7f1788f28c1508  577510            LGA
# 1847299  577592-b92f730e10a74530b47f997a99de1497  577592            IAD
#
#          destination destination_airport  seats  return_flight_booked  \
# 0            Houston                 EFD      1                  True
# 1           Montreal                 YHU      1                  True
# 2            Seattle                 SEA      2                  True
# 3        San Antonio                 SKF      1                  True
# 4           New York                 LGA      1                  True
# ...              ...                 ...    ...                   ...
# 1847295     New York                 LGA      1                  True
# 1847296      Houston                 IAH      1                  True
# 1847297      Houston                 IAH      2                  True
# 1847298       Denver                 DEN      1                  True
# 1847299    Nashville                 BNA      1                  True
#
#              departure_time         return_time  checked_bags  \
# 0       2023-04-02 07:00:00 2023-04-06 07:00:00             0
# 1       2023-04-04 07:00:00 2023-04-17 07:00:00             0
# 2       2023-04-01 10:00:00 2023-04-07 10:00:00             0
# 3       2023-04-04 11:00:00 2023-04-05 11:00:00             0
# 4       2023-03-31 07:00:00 2023-04-02 07:00:00             1
# ...                     ...                 ...           ...
# 1847295 2023-03-24 08:00:00 2023-03-25 08:00:00             0
# 1847296 2023-03-28 08:00:00 2023-03-31 08:00:00             0
# 1847297 2023-03-25 07:00:00 2023-03-25 07:00:00             1
# 1847298 2023-03-22 07:00:00 2023-03-26 07:00:00             0
# 1847299 2023-03-26 07:00:00 2023-03-27 07:00:00             0
#
#                      trip_airline  destination_airport_lat  \
# 0                 United Airlines                   29.607
# 1                  Delta Airlines                   45.517
# 2                 Alaska Airlines                   47.530
# 3                 United Airlines                   29.529
# 4                 JetBlue Airways                   40.640
# ...                           ...                      ...
# 1847295  KLM Royal Dutch Airlines                   40.640
# 1847296         American Airlines                   29.607
# 1847297        Singapore Airlines                   29.607
# 1847298           United Airlines                   39.858
# 1847299            Delta Airlines                   36.124
#
#          destination_airport_lon  base_fare_usd
# 0                        -95.159         479.31
# 1                        -73.417         575.78
# 2                       -122.302         336.72
# 3                        -98.279         295.37
# 4                        -73.779         694.26
# ...                          ...            ...
# 1847295                  -73.779          28.01
# 1847296                  -95.159         170.97
# 1847297                  -95.159         517.29
# 1847298                 -104.667         490.58
# 1847299                  -86.678         172.75
#
# [1847300 rows x 14 columns]

# %% [markdown]
# ### **Hotels**

# %% [markdown]
# #### Hotels - Overview

# %%
# 🧭 Quick overview of the dataset

print("🔹 SHAPE:")
print(df_hotels.shape)  # Rows and columns

print("\n🔹 COLUMNS:")
print(df_hotels.columns.tolist())  # List of column names

print("\n🔹 TYPES & NULLS:")
df_hotels.info()  # Column types, non-null counts

print("\n🔹 SAMPLE DATA:")
display(df_hotels.head())  # First few rows

print("\n🔹 BASIC STATS:")
display(df_hotels.describe(include='all'))  # Summary for all types

print("\n🔹 Missing Values per Column:")
missing_values_hotels = df_hotels.isna().sum()
missing_values_hotels = missing_values_hotels[missing_values_hotels > 0]  # Only colmuns with missing dataa
display(missing_values_hotels)
# Out:
# 🔹 SHAPE:
# (1918617, 7)
#
# 🔹 COLUMNS:
# ['trip_id', 'hotel_name', 'nights', 'rooms', 'check_in_time', 'check_out_time', 'hotel_per_room_usd']
#
# 🔹 TYPES & NULLS:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1918617 entries, 0 to 1918616
# Data columns (total 7 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   trip_id             object
#  1   hotel_name          object
#  2   nights              int64
#  3   rooms               int64
#  4   check_in_time       object
#  5   check_out_time      object
#  6   hotel_per_room_usd  int64
# dtypes: int64(3), object(4)
# memory usage: 102.5+ MB
#
# 🔹 SAMPLE DATA:
#                                    trip_id                   hotel_name  \
# 0  234666-99574aa53f30402ba04bfe2f3337c566         NH Hotel  - new york
# 1  234707-4c0cfdb5ff4a4cd8bda5feed22f790d7     Extended Stay  - toronto
# 2  234745-a8f944dc121c4003b16c108c9c590965        Shangri-La - edmonton
# 3  234905-c1e14087ef1f4a7a8413a12ef4208135          NH Hotel  - memphis
# 4  235101-cd0e752033db4f488fa75b5eb8feb2c8  Aman Resorts - jacksonville
#
#    nights  rooms            check_in_time       check_out_time  \
# 0       2      1   2023-01-20 11:46:41.16  2023-01-22 11:00:00
# 1       1      1   2023-01-19 15:38:40.11  2023-01-21 11:00:00
# 2       3      1   2023-01-19 13:05:43.98  2023-01-23 11:00:00
# 3       2      1  2023-01-16 11:50:56.985  2023-01-18 11:00:00
# 4       1      1  2023-01-16 17:09:21.375  2023-01-18 11:00:00
#
#    hotel_per_room_usd
# 0                 226
# 1                 114
# 2                 322
# 3                 228
# 4                 163
# 🔹 BASIC STATS:
#                                         trip_id                 hotel_name  \
# count                                   1918617                    1918617
# unique                                  1918617                       2798
# top     234549-d7bfb13b8de1489783e00723207629a1  Extended Stay  - new york
# freq                                          1                      14075
# mean                                        NaN                        NaN
# std                                         NaN                        NaN
# min                                         NaN                        NaN
# 25%                                         NaN                        NaN
# 50%                                         NaN                        NaN
# 75%                                         NaN                        NaN
# max                                         NaN                        NaN
#
#               nights         rooms        check_in_time       check_out_time  \
# count   1.918617e+06  1.918617e+06              1918617              1918617
# unique           NaN           NaN              1317413                 1221
# top              NaN           NaN  2023-03-19 11:00:00  2023-04-05 11:00:00
# freq             NaN           NaN                 1190                 6410
# mean    4.271452e+00  1.189341e+00                  NaN                  NaN
# std     4.488629e+00  4.879645e-01                  NaN                  NaN
# min    -2.000000e+00  0.000000e+00                  NaN                  NaN
# 25%     1.000000e+00  1.000000e+00                  NaN                  NaN
# 50%     3.000000e+00  1.000000e+00                  NaN                  NaN
# 75%     6.000000e+00  1.000000e+00                  NaN                  NaN
# max     1.070000e+02  6.000000e+00                  NaN                  NaN
#
#         hotel_per_room_usd
# count         1.918617e+06
# unique                 NaN
# top                    NaN
# freq                   NaN
# mean          1.773054e+02
# std           1.171834e+02
# min           8.000000e+00
# 25%           9.900000e+01
# 50%           1.480000e+02
# 75%           2.220000e+02
# max           2.377000e+03
# 🔹 Missing Values per Column:
# Series([], dtype: int64)

# %% [markdown]
# #### Hotels - Cleansing

# %% [markdown]
# Convert Time Columns to Datetime Format

# %%
# 1. Ensure datetime format for time columns
df_hotels["check_in_time"] = pd.to_datetime(df_hotels["check_in_time"], format="mixed", errors="coerce")
df_hotels["check_out_time"] = pd.to_datetime(df_hotels["check_out_time"], format="mixed", errors="coerce")

# %%
df_hotels
# Out:
#                                          trip_id  \
# 0        234666-99574aa53f30402ba04bfe2f3337c566
# 1        234707-4c0cfdb5ff4a4cd8bda5feed22f790d7
# 2        234745-a8f944dc121c4003b16c108c9c590965
# 3        234905-c1e14087ef1f4a7a8413a12ef4208135
# 4        235101-cd0e752033db4f488fa75b5eb8feb2c8
# ...                                          ...
# 1918612  234089-d69d29a671a74c0f9219bb3c6a45d2f3
# 1918613  234180-7ecead1843ec423a9a5d38902d8a8915
# 1918614  234354-e524d4a14bd34fbdb2725daa3a83cc80
# 1918615  234377-a4931088cf7e4293b71c17654f8f75c1
# 1918616  234549-d7bfb13b8de1489783e00723207629a1
#
#                            hotel_name  nights  rooms           check_in_time  \
# 0                NH Hotel  - new york       2      1 2023-01-20 11:46:41.160
# 1            Extended Stay  - toronto       1      1 2023-01-19 15:38:40.110
# 2               Shangri-La - edmonton       3      1 2023-01-19 13:05:43.980
# 3                 NH Hotel  - memphis       2      1 2023-01-16 11:50:56.985
# 4         Aman Resorts - jacksonville       1      1 2023-01-16 17:09:21.375
# ...                               ...     ...    ...                     ...
# 1918612  InterContinental  - columbus       6      1 2023-01-23 10:11:52.080
# 1918613            Fairmont - calgary      13      1 2023-01-15 11:00:00.000
# 1918614  Choice Hotels - indianapolis       2      1 2023-01-19 10:49:04.665
# 1918615               Hyatt - houston      10      2 2023-01-22 11:00:00.000
# 1918616          Radisson  - hamilton       1      1 2023-01-18 18:06:41.535
#
#              check_out_time  hotel_per_room_usd
# 0       2023-01-22 11:00:00                 226
# 1       2023-01-21 11:00:00                 114
# 2       2023-01-23 11:00:00                 322
# 3       2023-01-18 11:00:00                 228
# 4       2023-01-18 11:00:00                 163
# ...                     ...                 ...
# 1918612 2023-01-29 11:00:00                  57
# 1918613 2023-01-28 11:00:00                 157
# 1918614 2023-01-21 11:00:00                 237
# 1918615 2023-02-01 11:00:00                  86
# 1918616 2023-01-20 11:00:00                 436
#
# [1918617 rows x 7 columns]

# %% [markdown]
# #### Hotels - Feature Engineering

# %% [markdown]
# Extract User ID from Trip ID

# %%
df_hotels['user_id'] = df_hotels['trip_id'].str.extract(r'^([^-]+)')

# %% [markdown]
# Calculated nights ≠ Actual nights spent in the room
#
# It's the number of billable nights based on hotel policy, not necessarily physical presence overnight.

# %%
from datetime import datetime, timedelta
import pandas as pd

# Hotel rules
CHECKIN_TIME = datetime.strptime("15:00", "%H:%M").time()
CHECKOUT_TIME = datetime.strptime("11:00", "%H:%M").time()
GRACE_PERIOD = timedelta(hours=1)  # Grace period: 1 hour after official checkout time

# Realistic nights calculation function based on hotel logic
def calculate_nights_realistic(row):
    check_in = row["check_in_time"]
    check_out = row["check_out_time"]

    if pd.isna(check_in) or pd.isna(check_out):
        return None  # Missing values

    check_in_date = check_in.date()
    check_out_date = check_out.date()

    # Base number of nights = difference in calendar days
    nights = (check_out_date - check_in_date).days

    # Checkout deadline including grace period
    checkout_deadline = datetime.combine(check_out_date, CHECKOUT_TIME) + GRACE_PERIOD

    if check_out > checkout_deadline:
        nights += 1  # Late checkout → extra night

    return nights


# 2. Calculate nights using realistic hotel logic
df_hotels["nights_calculated"] = df_hotels.apply(calculate_nights_realistic, axis=1)

# 3. Compare with original 'nights' column
df_hotels["nights_diff"] = df_hotels["nights_calculated"] - df_hotels["nights"]

# 4. Show discrepancies if any
inconsistent = df_hotels[df_hotels["nights_diff"] != 0]

print("✅ First rows with calculated and reported nights:")
print(df_hotels[["check_in_time", "check_out_time", "nights", "nights_calculated", "nights_diff"]].head())

if not inconsistent.empty:
    print("\n⚠️ Bookings with discrepancies:")
    print(inconsistent[["check_in_time", "check_out_time", "nights", "nights_calculated", "nights_diff"]])
else:
    print("\n🎉 All bookings are correctly calculated!")
# Out:
# ✅ First rows with calculated and reported nights:
#             check_in_time      check_out_time  nights  nights_calculated  \
# 0 2023-01-20 11:46:41.160 2023-01-22 11:00:00       2                  2
# 1 2023-01-19 15:38:40.110 2023-01-21 11:00:00       1                  2
# 2 2023-01-19 13:05:43.980 2023-01-23 11:00:00       3                  4
# 3 2023-01-16 11:50:56.985 2023-01-18 11:00:00       2                  2
# 4 2023-01-16 17:09:21.375 2023-01-18 11:00:00       1                  2
#
#    nights_diff
# 0            0
# 1            1
# 2            1
# 3            0
# 4            1
#
# ⚠️ Bookings with discrepancies:
#                   check_in_time      check_out_time  nights  \
# 1       2023-01-19 15:38:40.110 2023-01-21 11:00:00       1
# 2       2023-01-19 13:05:43.980 2023-01-23 11:00:00       3
# 4       2023-01-16 17:09:21.375 2023-01-18 11:00:00       1
# 8       2023-01-17 19:47:43.395 2023-01-22 11:00:00       4
# 9       2023-01-16 15:24:06.660 2023-01-21 11:00:00       4
# ...                         ...                 ...     ...
# 1918604 2023-01-18 18:41:57.120 2023-01-22 11:00:00       3
# 1918607 2023-01-16 13:53:40.515 2023-01-19 11:00:00       2
# 1918609 2023-01-17 13:02:57.300 2023-01-19 11:00:00       1
# 1918611 2023-01-22 12:01:41.745 2023-01-23 11:00:00       0
# 1918616 2023-01-18 18:06:41.535 2023-01-20 11:00:00       1
#
#          nights_calculated  nights_diff
# 1                        2            1
# 2                        4            1
# 4                        2            1
# 8                        5            1
# 9                        5            1
# ...                    ...          ...
# 1918604                  4            1
# 1918607                  3            1
# 1918609                  2            1
# 1918611                  1            1
# 1918616                  2            1
#
# [1136731 rows x 5 columns]

# %% [markdown]
# Extracting Hotel Brand and City from Hotel Name Column

# %%
# Split 'hotel_name' into two new columns: brand and city
df_hotels[["hotel_brand", "hotel_city"]] = df_hotels["hotel_name"].str.split(" - ", expand=True)

# Capitalize the first letter of each word in the city name
df_hotels["hotel_city"] = df_hotels["hotel_city"].str.title()

# %% [markdown]
# Transform: df_hotels["hotel_per_room_usd"] into float type

# %%
df_hotels["hotel_per_room_usd"] = df_hotels["hotel_per_room_usd"].astype(float)

# %% [markdown]
# Review Results and Determine Export Strategy

# %%
df_hotels = df_hotels[
    ['trip_id', 'user_id', 'hotel_name', 'hotel_brand', 'hotel_city',
     'check_in_time', 'check_out_time', 'nights', 'nights_calculated', 'nights_diff',
     'rooms', 'hotel_per_room_usd']
]

df_hotels = df_hotels [
    ['trip_id', 'user_id', 'hotel_brand', 'hotel_city',
     'check_in_time', 'check_out_time', 'nights_calculated',
     'rooms', 'hotel_per_room_usd']
]

df_hotels_silver = df_hotels

df_hotels_silver
# Out:
#                                          trip_id user_id        hotel_brand  \
# 0        234666-99574aa53f30402ba04bfe2f3337c566  234666          NH Hotel
# 1        234707-4c0cfdb5ff4a4cd8bda5feed22f790d7  234707     Extended Stay
# 2        234745-a8f944dc121c4003b16c108c9c590965  234745         Shangri-La
# 3        234905-c1e14087ef1f4a7a8413a12ef4208135  234905          NH Hotel
# 4        235101-cd0e752033db4f488fa75b5eb8feb2c8  235101       Aman Resorts
# ...                                          ...     ...                ...
# 1918612  234089-d69d29a671a74c0f9219bb3c6a45d2f3  234089  InterContinental
# 1918613  234180-7ecead1843ec423a9a5d38902d8a8915  234180           Fairmont
# 1918614  234354-e524d4a14bd34fbdb2725daa3a83cc80  234354      Choice Hotels
# 1918615  234377-a4931088cf7e4293b71c17654f8f75c1  234377              Hyatt
# 1918616  234549-d7bfb13b8de1489783e00723207629a1  234549          Radisson
#
#            hotel_city           check_in_time      check_out_time  \
# 0            New York 2023-01-20 11:46:41.160 2023-01-22 11:00:00
# 1             Toronto 2023-01-19 15:38:40.110 2023-01-21 11:00:00
# 2            Edmonton 2023-01-19 13:05:43.980 2023-01-23 11:00:00
# 3             Memphis 2023-01-16 11:50:56.985 2023-01-18 11:00:00
# 4        Jacksonville 2023-01-16 17:09:21.375 2023-01-18 11:00:00
# ...               ...                     ...                 ...
# 1918612      Columbus 2023-01-23 10:11:52.080 2023-01-29 11:00:00
# 1918613       Calgary 2023-01-15 11:00:00.000 2023-01-28 11:00:00
# 1918614  Indianapolis 2023-01-19 10:49:04.665 2023-01-21 11:00:00
# 1918615       Houston 2023-01-22 11:00:00.000 2023-02-01 11:00:00
# 1918616      Hamilton 2023-01-18 18:06:41.535 2023-01-20 11:00:00
#
#          nights_calculated  rooms  hotel_per_room_usd
# 0                        2      1               226.0
# 1                        2      1               114.0
# 2                        4      1               322.0
# 3                        2      1               228.0
# 4                        2      1               163.0
# ...                    ...    ...                 ...
# 1918612                  6      1                57.0
# 1918613                 13      1               157.0
# 1918614                  2      1               237.0
# 1918615                 10      2                86.0
# 1918616                  2      1               436.0
#
# [1918617 rows x 9 columns]

# %% [markdown]
# ### **Sessions**

# %% [markdown]
# #### Sessions - Overview

# %%
# 🧭 Quick overview of the dataset

print("🔹 SHAPE:")
print(df_sessions.shape)  # Rows and columns

print("\n🔹 COLUMNS:")
print(df_sessions.columns.tolist())  # List of column names

print("\n🔹 TYPES & NULLS:")
df_sessions.info()  # Column types, non-null counts

print("\n🔹 SAMPLE DATA:")
display(df_sessions.head())  # First few rows

print("\n🔹 BASIC STATS:")
display(df_sessions.describe(include='all'))  # Summary for all types

print("\n🔹 Missing Values per Column:")
missing_values_sessions = df_sessions.isna().sum()
missing_values_sessions = missing_values_sessions[missing_values_sessions > 0]  # Only colmuns with missing dataa
display(missing_values_sessions)
# Out:
# 🔹 SHAPE:
# (5408063, 13)
#
# 🔹 COLUMNS:
# ['session_id', 'user_id', 'trip_id', 'session_start', 'session_end', 'flight_discount', 'hotel_discount', 'flight_discount_amount', 'hotel_discount_amount', 'flight_booked', 'hotel_booked', 'page_clicks', 'cancellation']
#
# 🔹 TYPES & NULLS:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5408063 entries, 0 to 5408062
# Data columns (total 13 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   session_id              object
#  1   user_id                 int64
#  2   trip_id                 object
#  3   session_start           object
#  4   session_end             object
#  5   flight_discount         bool
#  6   hotel_discount          bool
#  7   flight_discount_amount  float64
#  8   hotel_discount_amount   float64
#  9   flight_booked           bool
#  10  hotel_booked            bool
#  11  page_clicks             int64
#  12  cancellation            bool
# dtypes: bool(5), float64(2), int64(2), object(4)
# memory usage: 355.9+ MB
#
# 🔹 SAMPLE DATA:
#                                 session_id  user_id  \
# 0  841803-95c93659053948049c73106ffdcf4df6   841803
# 1  841804-bf1bfe452c4d4372b04d9612134006e7   841804
# 2  841805-70d695ee6540481bae7750e368c10443   841805
# 3  841806-a03ac981d1c847979765669ca871a0cb   841806
# 4  841807-4febb023cd414a6196fc026af1928bfb   841807
#
#                                    trip_id        session_start  \
# 0  841803-31d33d39b08f477bb8d9dd3b0dcbf1d3  2023-05-17 19:40:00
# 1                                      NaN  2023-05-17 22:40:00
# 2  841805-506d17340ffa41659736fd258138a9b5  2023-05-17 21:10:00
# 3                                      NaN  2023-05-17 21:49:00
# 4                                      NaN  2023-05-17 20:28:00
#
#            session_end  flight_discount  hotel_discount  \
# 0  2023-05-17 19:43:48            False           False
# 1  2023-05-17 22:41:09            False           False
# 2  2023-05-17 21:13:03            False           False
# 3  2023-05-17 21:54:09             True            True
# 4  2023-05-17 20:28:29            False           False
#
#    flight_discount_amount  hotel_discount_amount  flight_booked  hotel_booked  \
# 0                     NaN                    NaN           True          True
# 1                     NaN                    NaN          False         False
# 2                     NaN                    NaN           True          True
# 3                     0.2                    0.2          False         False
# 4                     NaN                    NaN          False         False
#
#    page_clicks  cancellation
# 0           30         False
# 1            9         False
# 2           24         False
# 3           42         False
# 4            4         False
# 🔹 BASIC STATS:
#                                      session_id       user_id  \
# count                                   5408063  5.408063e+06
# unique                                  5408063           NaN
# top     841802-0161005c612646c696d80acf427b4d0a           NaN
# freq                                          1           NaN
# mean                                        NaN  3.988590e+05
# std                                         NaN  2.707599e+05
# min                                         NaN  0.000000e+00
# 25%                                         NaN  1.643270e+05
# 50%                                         NaN  3.641720e+05
# 75%                                         NaN  6.031520e+05
# max                                         NaN  1.020925e+06
#
#                                         trip_id        session_start  \
# count                                   2335845              5408063
# unique                                  2245175               960389
# top     192187-8643d744ca5e404399b02c4cfe83c15b  2023-03-27 20:46:00
# freq                                          2                   50
# mean                                        NaN                  NaN
# std                                         NaN                  NaN
# min                                         NaN                  NaN
# 25%                                         NaN                  NaN
# 50%                                         NaN                  NaN
# 75%                                         NaN                  NaN
# max                                         NaN                  NaN
#
#                 session_end flight_discount hotel_discount  \
# count               5408063         5408063        5408063
# unique              4868259               2              2
# top     2023-03-26 11:23:37           False          False
# freq                      8         4431597        4626013
# mean                    NaN             NaN            NaN
# std                     NaN             NaN            NaN
# min                     NaN             NaN            NaN
# 25%                     NaN             NaN            NaN
# 50%                     NaN             NaN            NaN
# 75%                     NaN             NaN            NaN
# max                     NaN             NaN            NaN
#
#         flight_discount_amount  hotel_discount_amount flight_booked  \
# count            885796.000000          691380.000000       5408063
# unique                     NaN                    NaN             2
# top                        NaN                    NaN         False
# freq                       NaN                    NaN       3416355
# mean                  0.139765               0.110950           NaN
# std                   0.085191               0.062021           NaN
# min                   0.050000               0.050000           NaN
# 25%                   0.100000               0.050000           NaN
# 50%                   0.100000               0.100000           NaN
# 75%                   0.200000               0.150000           NaN
# max                   0.850000               0.650000           NaN
#
#        hotel_booked   page_clicks cancellation
# count       5408063  5.408063e+06      5408063
# unique            2           NaN            2
# top           False           NaN        False
# freq        3398776           NaN      5317393
# mean            NaN  1.876603e+01          NaN
# std             NaN  2.218070e+01          NaN
# min             NaN  0.000000e+00          NaN
# 25%             NaN  7.000000e+00          NaN
# 50%             NaN  1.500000e+01          NaN
# 75%             NaN  2.300000e+01          NaN
# max             NaN  2.421000e+03          NaN
# 🔹 Missing Values per Column:
# trip_id                   3072218
# flight_discount_amount    4522267
# hotel_discount_amount     4716683
# dtype: int64

# %% [markdown]
# #### Sessions - Cleansing

# %%
# 1. Ensure datetime format for time columns
df_sessions["session_start"] = pd.to_datetime(df_sessions["session_start"], format="mixed", errors="coerce")
df_sessions["session_end"] = pd.to_datetime(df_sessions["session_end"], format="mixed", errors="coerce")

# %%
df_sessions = df_sessions[
    ['session_id', 'user_id', 'trip_id',
     'session_start', 'session_end',
     'flight_discount', 'flight_discount_amount',
     'hotel_discount', 'hotel_discount_amount',
     'page_clicks', 'flight_booked', 'hotel_booked', 'cancellation']
]
df_sessions_silver = df_sessions

df_sessions_silver
# Out:
#                                       session_id  user_id  \
# 0        841803-95c93659053948049c73106ffdcf4df6   841803
# 1        841804-bf1bfe452c4d4372b04d9612134006e7   841804
# 2        841805-70d695ee6540481bae7750e368c10443   841805
# 3        841806-a03ac981d1c847979765669ca871a0cb   841806
# 4        841807-4febb023cd414a6196fc026af1928bfb   841807
# ...                                          ...      ...
# 5408058  841798-022fd195dce84aeca41492a209f4d456   841798
# 5408059  841799-1852098e3f9c4dc084cf808ae3972338   841799
# 5408060  841800-24d4e9b0034643ca94ad6b08ebd694df   841800
# 5408061  841801-ab1e9225713e44639c2238f7b4241662   841801
# 5408062  841802-0161005c612646c696d80acf427b4d0a   841802
#
#                                          trip_id       session_start  \
# 0        841803-31d33d39b08f477bb8d9dd3b0dcbf1d3 2023-05-17 19:40:00
# 1                                            NaN 2023-05-17 22:40:00
# 2        841805-506d17340ffa41659736fd258138a9b5 2023-05-17 21:10:00
# 3                                            NaN 2023-05-17 21:49:00
# 4                                            NaN 2023-05-17 20:28:00
# ...                                          ...                 ...
# 5408058  841798-67b1366799aa4659852a38bcedfb4fdc 2023-05-17 19:20:00
# 5408059                                      NaN 2023-05-17 02:05:00
# 5408060  841800-8710f272ab484cbd8654264d56370fc0 2023-05-17 08:14:00
# 5408061  841801-e6338477bfc04ae1bd4e3d62b407bf1e 2023-05-17 11:30:00
# 5408062  841802-236999fbfdf6496a87a06588c81d367d 2023-05-17 12:53:00
#
#                 session_end  flight_discount  flight_discount_amount  \
# 0       2023-05-17 19:43:48            False                     NaN
# 1       2023-05-17 22:41:09            False                     NaN
# 2       2023-05-17 21:13:03            False                     NaN
# 3       2023-05-17 21:54:09             True                     0.2
# 4       2023-05-17 20:28:29            False                     NaN
# ...                     ...              ...                     ...
# 5408058 2023-05-17 19:21:14            False                     NaN
# 5408059 2023-05-17 02:06:47            False                     NaN
# 5408060 2023-05-17 08:16:19            False                     NaN
# 5408061 2023-05-17 11:32:30            False                     NaN
# 5408062 2023-05-17 12:56:58            False                     NaN
#
#          hotel_discount  hotel_discount_amount  page_clicks  flight_booked  \
# 0                 False                    NaN           30           True
# 1                 False                    NaN            9          False
# 2                 False                    NaN           24           True
# 3                  True                   0.20           42          False
# 4                 False                    NaN            4          False
# ...                 ...                    ...          ...            ...
# 5408058           False                    NaN           10          False
# 5408059           False                    NaN           15          False
# 5408060            True                   0.05           19           True
# 5408061           False                    NaN           20           True
# 5408062           False                    NaN           32           True
#
#          hotel_booked  cancellation
# 0                True         False
# 1               False         False
# 2                True         False
# 3               False         False
# 4               False         False
# ...               ...           ...
# 5408058          True         False
# 5408059         False         False
# 5408060         False         False
# 5408061          True         False
# 5408062          True         False
#
# [5408063 rows x 13 columns]

# %% [markdown]
# ***Handling Missing Values***
#
# - The missing `trip_id` values are not critical for the data analysis, as we can rely on `user_id` or `session_id` in combination with `flight_booked` and/or `hotel_booked` as alternative identifiers.
#
# - For `flight_discount_amount` and `hotel_discount_amount`, we assume that the bookings were either made without any discounts applied, or that no bookings were made during those sessions. These cases can be filtered or handled in a later stage of the analysis.

# %% [markdown]
# ### **Users**

# %% [markdown]
# #### Users - Overview

# %%
# 🧭 Quick overview of the dataset

print("🔹 SHAPE:")
print(df_users.shape)  # Rows and columns

print("\n🔹 COLUMNS:")
print(df_users.columns.tolist())  # List of column names

print("\n🔹 TYPES & NULLS:")
df_users.info()  # Column types, non-null counts

print("\n🔹 SAMPLE DATA:")
display(df_users.head())  # First few rows

print("\n🔹 BASIC STATS:")
display(df_users.describe(include='all'))  # Summary for all types

print("\n🔹 Missing Values per Column:")
missing_values_users = df_users.isna().sum()
missing_values_users = missing_values_users[missing_values_users > 0]  # Only colmuns with missing dataa
display(missing_values_users)
# Out:
# 🔹 SHAPE:
# (1020926, 11)
#
# 🔹 COLUMNS:
# ['user_id', 'birthdate', 'gender', 'married', 'has_children', 'home_country', 'home_city', 'home_airport', 'home_airport_lat', 'home_airport_lon', 'sign_up_date']
#
# 🔹 TYPES & NULLS:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020926 entries, 0 to 1020925
# Data columns (total 11 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   user_id           1020926 non-null  int64
#  1   birthdate         1020926 non-null  object
#  2   gender            1020926 non-null  object
#  3   married           1020926 non-null  bool
#  4   has_children      1020926 non-null  bool
#  5   home_country      1020926 non-null  object
#  6   home_city         1020926 non-null  object
#  7   home_airport      1020926 non-null  object
#  8   home_airport_lat  1020926 non-null  float64
#  9   home_airport_lon  1020926 non-null  float64
#  10  sign_up_date      1020926 non-null  object
# dtypes: bool(2), float64(2), int64(1), object(6)
# memory usage: 72.0+ MB
#
# 🔹 SAMPLE DATA:
#    user_id   birthdate gender  married  has_children home_country  \
# 0        0  1990-01-22      F    False         False          usa
# 1        1  2000-11-08      M    False         False          usa
# 2        2  1992-09-21      M    False         False          usa
# 3        3  1996-11-27      F    False         False          usa
# 4        4  1978-01-05      M     True          True          usa
#
#           home_city home_airport  home_airport_lat  home_airport_lon  \
# 0       minneapolis          MSP            44.880           -93.217
# 1  colorado springs          COS            38.806          -104.700
# 2          portland          PDX            45.589          -122.597
# 3           houston          IAH            29.980           -95.340
# 4          honolulu          HNL            21.316          -157.927
#
#   sign_up_date
# 0   2021-04-01
# 1   2021-04-01
# 2   2021-04-01
# 3   2021-04-01
# 4   2021-04-01
# 🔹 BASIC STATS:
#              user_id   birthdate   gender  married has_children home_country  \
# count   1.020926e+06     1020926  1020926  1020926      1020926      1020926
# unique           NaN       22581        3        2            2            2
# top              NaN  2006-09-03        M    False        False          usa
# freq             NaN         169   558986   626109       701289       848354
# mean    5.104625e+05         NaN      NaN      NaN          NaN          NaN
# std     2.947161e+05         NaN      NaN      NaN          NaN          NaN
# min     0.000000e+00         NaN      NaN      NaN          NaN          NaN
# 25%     2.552312e+05         NaN      NaN      NaN          NaN          NaN
# 50%     5.104625e+05         NaN      NaN      NaN          NaN          NaN
# 75%     7.656938e+05         NaN      NaN      NaN          NaN          NaN
# max     1.020925e+06         NaN      NaN      NaN          NaN          NaN
#
#        home_city home_airport  home_airport_lat  home_airport_lon sign_up_date
# count    1020926      1020926      1.020926e+06      1.020926e+06      1020926
# unique       105          159               NaN               NaN          831
# top     new york          JFK               NaN               NaN   2023-05-15
# freq      121290        60711               NaN               NaN         3326
# mean         NaN          NaN      3.855352e+01     -9.392036e+01          NaN
# std          NaN          NaN      6.120248e+00      1.809645e+01          NaN
# min          NaN          NaN      2.131600e+01     -1.579270e+02          NaN
# 25%          NaN          NaN      3.394200e+01     -1.120080e+02          NaN
# 50%          NaN          NaN      3.929700e+01     -8.997700e+01          NaN
# 75%          NaN          NaN      4.227600e+01     -7.745600e+01          NaN
# max          NaN          NaN      6.125100e+01     -6.349900e+01          NaN
# 🔹 Missing Values per Column:
# Series([], dtype: int64)

# %% [markdown]
# .describe

# %%
df_users.describe(include="all")
# Out:
#              user_id   birthdate   gender  married has_children home_country  \
# count   1.020926e+06     1020926  1020926  1020926      1020926      1020926
# unique           NaN       22581        3        2            2            2
# top              NaN  2006-09-03        M    False        False          usa
# freq             NaN         169   558986   626109       701289       848354
# mean    5.104625e+05         NaN      NaN      NaN          NaN          NaN
# std     2.947161e+05         NaN      NaN      NaN          NaN          NaN
# min     0.000000e+00         NaN      NaN      NaN          NaN          NaN
# 25%     2.552312e+05         NaN      NaN      NaN          NaN          NaN
# 50%     5.104625e+05         NaN      NaN      NaN          NaN          NaN
# 75%     7.656938e+05         NaN      NaN      NaN          NaN          NaN
# max     1.020925e+06         NaN      NaN      NaN          NaN          NaN
#
#        home_city home_airport  home_airport_lat  home_airport_lon sign_up_date
# count    1020926      1020926      1.020926e+06      1.020926e+06      1020926
# unique       105          159               NaN               NaN          831
# top     new york          JFK               NaN               NaN   2023-05-15
# freq      121290        60711               NaN               NaN         3326
# mean         NaN          NaN      3.855352e+01     -9.392036e+01          NaN
# std          NaN          NaN      6.120248e+00      1.809645e+01          NaN
# min          NaN          NaN      2.131600e+01     -1.579270e+02          NaN
# 25%          NaN          NaN      3.394200e+01     -1.120080e+02          NaN
# 50%          NaN          NaN      3.929700e+01     -8.997700e+01          NaN
# 75%          NaN          NaN      4.227600e+01     -7.745600e+01          NaN
# max          NaN          NaN      6.125100e+01     -6.349900e+01          NaN

# %%
df_users.shape
# Out:
# (1020926, 11)

# %% [markdown]
# #### Users - Cleansing

# %% [markdown]
# Convert Signup Column to Datetime Format

# %%
# 1. Ensure datetime format for time columns
df_users["sign_up_date"] = pd.to_datetime(df_users["sign_up_date"], format="mixed", errors="coerce")

# %% [markdown]
# Birthdate: Datetime Conversion and Formatting

# %%
df_users["birthdate"] = pd.to_datetime(df_users["birthdate"], errors="coerce")
df_users["birthdate_str"] = df_users["birthdate"].dt.strftime("%Y-%m-%d")

# %% [markdown]
# Standarzise Gender Values

# %%
df_users["gender"] = df_users["gender"].replace({
    "F": "Female",
    "M": "Male",
    "O": "Other"
})

# %% [markdown]
# Standarsize Home City Values

# %%
df_users["home_city"] = df_users["home_city"].str.title()

# %%
df_users = df_users[
    ['user_id',
     'birthdate', 'birthdate_str', 'gender', 'married', 'has_children',
     'home_country', 'home_city', 'home_airport', 'home_airport_lat', 'home_airport_lon',
     'sign_up_date']
]

df_users_silver = df_users

df_users_silver
# Out:
#          user_id  birthdate birthdate_str  gender  married  has_children  \
# 0              0 1990-01-22    1990-01-22  Female    False         False
# 1              1 2000-11-08    2000-11-08    Male    False         False
# 2              2 1992-09-21    1992-09-21    Male    False         False
# 3              3 1996-11-27    1996-11-27  Female    False         False
# 4              4 1978-01-05    1978-01-05    Male     True          True
# ...          ...        ...           ...     ...      ...           ...
# 1020921  1020921 2005-05-22    2005-05-22    Male    False          True
# 1020922  1020922 1985-06-15    1985-06-15    Male     True         False
# 1020923  1020923 1995-09-21    1995-09-21  Female    False         False
# 1020924  1020924 2006-11-19    2006-11-19  Female    False         False
# 1020925  1020925 1978-04-27    1978-04-27    Male    False          True
#
#         home_country         home_city home_airport  home_airport_lat  \
# 0                usa       Minneapolis          MSP            44.880
# 1                usa  Colorado Springs          COS            38.806
# 2                usa          Portland          PDX            45.589
# 3                usa           Houston          IAH            29.980
# 4                usa          Honolulu          HNL            21.316
# ...              ...               ...          ...               ...
# 1020921          usa        Shreveport          BAD            32.502
# 1020922          usa     Oklahoma City          TIK            35.415
# 1020923       canada           Toronto          YKZ            43.862
# 1020924          usa           Lincoln          LNK            40.851
# 1020925          usa           Memphis          MEM            35.042
#
#          home_airport_lon sign_up_date
# 0                 -93.217   2021-04-01
# 1                -104.700   2021-04-01
# 2                -122.597   2021-04-01
# 3                 -95.340   2021-04-01
# 4                -157.927   2021-04-01
# ...                   ...          ...
# 1020921           -93.663   2023-07-20
# 1020922           -97.386   2023-07-20
# 1020923           -79.370   2023-07-20
# 1020924           -96.759   2023-07-20
# 1020925           -89.977   2023-07-20
#
# [1020926 rows x 12 columns]

# %% [markdown]
# ### **Export to S3 Silver Layer**

# %%
import pandas as pd
import s3fs  # wichtig für s3:// Zugriff mit Pandas

# Beispielhafte DataFrames – bitte sicherstellen, dass diese existieren
tables = {
    "flights": df_flights_silver,
    "users": df_users_silver,
    "hotels": df_hotels_silver,
    "sessions": df_sessions_silver
}

# Pfad zum Silver Layer in deinem S3-Bucket
silver_base_path = "s3://lakehouse-masteryproject-2025/silver/"

# Schreibe jede Tabelle als CSV in den Silver Layer
for name, df in tables.items():
    try:
        path = f"{silver_base_path}{name}.csv"
        df.to_csv(path, index=False)
        print(f"✅ Hochgeladen: {path}")
    except Exception as e:
        print(f"❌ Fehler bei {name}: {e}")
# Out:
# ✅ Hochgeladen: s3://lakehouse-masteryproject-2025/silver/flights.csv
# ✅ Hochgeladen: s3://lakehouse-masteryproject-2025/silver/users.csv
# ✅ Hochgeladen: s3://lakehouse-masteryproject-2025/silver/hotels.csv
# ✅ Hochgeladen: s3://lakehouse-masteryproject-2025/silver/sessions.csv

# %% [markdown]
# # gg
